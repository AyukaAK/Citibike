# %% [markdown]
# # Analyze the live citibike data
# ## Saved the jason file every 10 minutes for 24h on July 5, 2022

# %%
import requests
import pandas as pd
import datetime
import json

# %%
url_status = 'https://gbfs.citibikenyc.com/gbfs/en/station_status.json'

# %%
response = requests.get (url_status)
data = response.json()

# %%
print (data['data']['stations'])
# Out:
# [{'last_reported': 1656077952, 'num_docks_available': 55, 'is_renting': 0, 'num_bikes_disabled': 0, 'eightd_has_available_keys': False, 'station_status': 'out_of_service', 'num_bikes_available': 0, 'num_docks_disabled': 0, 'is_returning': 0, 'is_installed': 0, 'station_id': '72', 'legacy_id': '72', 'num_ebikes_available': 0}, {'last_reported': 1657423892, 'num_docks_available': 15, 'is_renting': 1, 'num_bikes_disabled': 3, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 14, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '79', 'legacy_id': '79', 'num_ebikes_available': 1}, {'last_reported': 1657422246, 'num_docks_available': 0, 'is_renting': 1, 'num_bikes_disabled': 2, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 25, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '82', 'legacy_id': '82', 'num_ebikes_available': 0}, {'last_reported': 1657423236, 'num_docks_available': 17, 'is_renting': 1, 'num_bikes_disabled': 3, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 42, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '83', 'legacy_id': '83', 'num_ebikes_available': 0}, {'last_reported': 86400, 'num_docks_available': 0, 'is_renting': 0, 'num_bikes_disabled': 0, 'eightd_has_available_keys': False, 'station_status': 'out_of_service', 'num_bikes_available': 0, 'num_docks_disabled': 0, 'is_returning': 0, 'is_installed': 0, 'station_id': '116', 'legacy_id': '116', 'num_ebikes_available': 0}, {'last_reported': 1657422028, 'num_docks_available': 10, 'is_renting': 1, 'num_bikes_disabled': 2, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 41, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '119', 'legacy_id': '119', 'num_ebikes_available': 0}, {'last_reported': 1657423513, 'num_docks_available': 17, 'is_renting': 1, 'num_bikes_disabled': 0, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 2, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '120', 'legacy_id': '120', 'num_ebikes_available': 1}, {'last_reported': 1657423791, 'num_docks_available': 12, 'is_renting': 1, 'num_bikes_disabled': 6, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 12, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '127', 'legacy_id': '127', 'num_ebikes_available': 0}, {'last_reported': 1657424065, 'num_docks_available': 3, 'is_renting': 1, 'num_bikes_disabled': 5, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 46, 'num_docks_disabled': 1, 'is_returning': 1, 'is_installed': 1, 'station_id': '128', 'legacy_id': '128', 'num_ebikes_available': 0}, {'last_reported': 1657423738, 'num_docks_available': 1, 'is_renting': 1, 'num_bikes_disabled': 0, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 49, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '143', 'legacy_id': '143', 'num_ebikes_available': 0}, {'last_reported': 1657423163, 'num_docks_available': 0, 'is_renting': 1, 'num_bikes_disabled': 3, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 55, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '144', 'legacy_id': '144', 'num_ebikes_available': 0}, {'last_reported': 1657423874, 'num_docks_available': 30, 'is_renting': 1, 'num_bikes_disabled': 3, 'eightd_has_available_keys': False, 'station_status': 'active', 'num_bikes_available': 22, 'num_docks_disabled': 0, 'is_returning': 1, 'is_installed': 1, 'station_id': '146', 'legacy_id': '146', 'num_ebikes_available': 0}, {'last_reported': 1657424297, 'num_docks_available': 21, 'is_renting': 1, 'num_bikes_disabled': 3, 'eightd_has_available_keys': False, 'stat ...

# %%
df = pd.DataFrame(data['data']['stations'])
df
# Out:
#       last_reported  num_docks_available  is_renting  num_bikes_disabled  \
# 0        1656077952                   55           0                   0
# 1        1657423892                   15           1                   3
# 2        1657422246                    0           1                   2
# 3        1657423236                   17           1                   3
# 4             86400                    0           0                   0
# ...             ...                  ...         ...                 ...
# 1693          86400                    0           0                   0
# 1694          86400                    0           0                   0
# 1695     1657423750                   44           1                   0
# 1696     1657418427                    5           1                   3
# 1697     1657421653                   16           1                   1
#
#       eightd_has_available_keys  station_status  num_bikes_available  \
# 0                         False  out_of_service                    0
# 1                         False          active                   14
# 2                         False          active                   25
# 3                         False          active                   42
# 4                         False  out_of_service                    0
# ...                         ...             ...                  ...
# 1693                      False  out_of_service                    0
# 1694                      False  out_of_service                    0
# 1695                      False          active                    3
# 1696                      False          active                   25
# 1697                      False          active                    0
#
#       num_docks_disabled  is_returning  is_installed station_id legacy_id  \
# 0                      0             0             0         72        72
# 1                      0             1             1         79        79
# 2                      0             1             1         82        82
# 3                      0             1             1         83        83
# 4                      0             0             0        116       116
# ...                  ...           ...           ...        ...       ...
# 1693                   0             0             0       4827      4827
# 1694                   0             0             0       4829      4829
# 1695                   0             1             1       4830      4830
# 1696                   0             1             1       4834      4834
# 1697                   0             1             1       4873      4873
#
#       num_ebikes_available eightd_active_station_services valet
# 0                        0                            NaN   NaN
# 1                        1                            NaN   NaN
# 2                        0                            NaN   NaN
# 3                        0                            NaN   NaN
# 4                        0                            NaN   NaN
# ...                    ...                            ...   ...
# 1693                     0                            NaN   NaN
# 1694                     0                            NaN   NaN
# 1695                     0                            NaN   NaN
# 1696                     0                            NaN   NaN
# 1697                     0                            NaN   NaN
#
# [1698 rows x 15 columns]

# %% [markdown]
# # Step 1: prep

# %%
#Save one Json file from NOW to my computer - base file
open('Live_Data/station_status.json', 'wb').write(response.content)
# Out:
# 505016

# %%
#time stamp with the python module "datetime"
now = datetime.datetime.now()

# %%
#Save each Json file from each timestamp to my computer
open('Live_Data/station_status'+str(now)+'.json', 'wb').write(response.content)
# Out:
# 505016

# %%
#Step 1 in summary (each time I run this, the Json file gets saved from that time) 
import requests
import datetime
url_status = 'https://gbfs.citibikenyc.com/gbfs/en/station_status.json'
response = requests.get (url_status)
now = datetime.datetime.now()
open('Live_Data/station_status'+str(now)+'.json', 'wb').write(response.content)
# Out:
# 505014

# %% [markdown]
# # Step 2: Use while loop to run step 1 every 10 min
# ### create a file in VS code and run this code from the terminal because otherwise it freezes my jupyter notebook
#
# import time
# import requests
# import datetime
#
# while True:
#     time.sleep(300)
#     url_status = 'https://gbfs.citibikenyc.com/gbfs/en/station_status.json'
#     response = requests.get (url_status)
#     now = datetime.datetime.now()
#     open('Live_Data/station_status'+str(now)+'.json', 'wb').write(response.content)
#
#     print("Printed after 300 seconds.")

# %% [markdown]
# # Step 3: Use the files I got from step 2 to clean up and analyze
#
# #### Save the files I want to use into another file because the original file is still getting live jason files

# %% [markdown]
# ### Print the name of the files in the directory and create s a list

# %%
#Step 1
# import OS module
import os
 
# Get the list of all files and directories
path = "/Users/ayukakawakami/Desktop/LedeProgram/Project_2/Citibike_story/Live_Data_July_5"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
# prints all files
print(dir_list)
# Out:
# Files and directories in ' /Users/ayukakawakami/Desktop/LedeProgram/Project_2/Citibike_story/Live_Data_July_5 ' :
# ['station_status2022-07-05 19:15:57.468857.json', 'station_status2022-07-05 07:35:34.072987.json', 'station_status2022-07-05 02:25:23.557745.json', 'station_status2022-07-05 22:46:02.853061.json', 'station_status2022-07-05 16:35:52.447431.json', 'station_status2022-07-05 03:15:25.243502.json', 'station_status2022-07-05 16:33:20.955970.json', 'station_status2022-07-05 05:35:29.856563.json', 'station_status2022-07-05 19:11:29.161426.json', 'station_status2022-07-05 21:05:59.425041.json', 'station_status2022-07-05 05:55:30.697043.json', 'station_status2022-07-05 02:15:23.274284.json', 'station_status2022-07-05 23:08:39.173120.json', 'station_status2022-07-05 06:35:32.146470.json', 'station_status2022-07-05 03:25:25.637622.json', 'station_status2022-07-05 04:05:26.812486.json', 'station_status2022-07-05 09:35:37.957115.json', 'station_status2022-07-05 11:35:41.974644.json', 'station_status2022-07-05 12:25:43.673851.json', 'station_status2022-07-05 12:45:44.283804.json', 'station_status2022-07-05 19:58:08.608018.json', 'station_status2022-07-05 18:15:55.387064.json', 'station_status2022-07-05 22:16:01.750318.json', 'station_status2022-07-05 08:25:35.427443.json', 'station_status2022-07-05 20:15:57.921641.json', 'station_status2022-07-05 23:19:43.198406.json', 'station_status2022-07-05 09:25:37.571178.json', 'station_status2022-07-05 07:45:34.460478.json', 'station_status2022-07-05 23:08:38.566323.json', 'station_status2022-07-05 14:05:47.028506.json', 'station_status2022-07-05 23:46:04.961576.json', 'station_status2022-07-05 01:08:03.572610.json', 'station_status2022-07-05 20:35:58.521399.json', 'station_status2022-07-05 15:05:49.501735.json', 'station_status2022-07-05 23:19:36.967252.json', 'station_status2022-07-05 19:11:28.501752.json', 'station_status2022-07-05 17:55:54.893490.json', 'station_status2022-07-05 16:25:52.244847.json', 'station_status2022-07-05 00:15:19.236154.json', 'station_status2022-07-05 12:55:44.661468.json', 'station_status2022-07-05 04:55:28.720500.json', 'station_status2022-07-05 11:15:41.267240.json', 'station_status2022-07-05 14:25:47.927688.json', 'station_status2022-07-05 16:55:53.146103.json', 'station_status2022-07-05 21:15:59.795916.json', 'station_status2022-07-05 12:05:43.005509.json', 'station_status2022-07-05 00:35:20.264517.json', 'station_status2022-07-05 23:56:05.363882.json', 'station_status2022-07-05 22:26:02.103504.json', 'station_status2022-07-05 13:45:46.443260.json', 'station_status2022-07-05 18:35:55.972591.json', 'station_status2022-07-05 22:56:03.111008.json', 'station_status2022-07-05 00:55:20.827713.json', 'station_status2022-07-05 14:35:48.261197.json', 'station_status2022-07-05 04:15:27.177933.json', 'station_status2022-07-05 22:36:02.483840.json', 'station_status2022-07-05 10:55:40.571537.json', 'station_status2022-07-05 20:25:58.323782.json', 'station_status2022-07-05 08:45:36.115604.json', 'station_status2022-07-05 13:55:46.636135.json', 'station_status2022-07-05 01:35:21.872792.json', 'station_status2022-07-05 07:05:33.002040.json', 'station_status2022-07-05 00:05:18.936750.json', 'station_status2022-07-05 10:25:39.590851.json', 'station_status2022-07-05 03:05:24.926133.json', 'station_status2022-07-05 17:25:54.186425.json', 'station_status2022-07-05 20:45:58.752401.json', 'station_status2022-07-05 11:05:40.930927.json', 'station_status2022-07-05 15:55:51.285779.json', 'station_status2022-07-05 06:05:30.920596.json', 'station_status2022-07-05 06:55:32.691988.json', 'station_status2022-07-05 11:25:41.621102.json', 'station_status2022-07-05 13:15:45.318089.json', 'station_status2022-07-05 02:45:24.213961.json', 'station_status2022-07-05 13:05:44.990026.json', 'station_status2022-07-05 10:35:39.996662.json', 'station_status2022-07-05 17:45:54.649144.json', 'station_status2022-07-05 18:05:55.212643.json', 'station_status2022-07-05 06:25:31.771882.json', 'station_status2022-07-05 23:26:04.211439.json', 'station_status2022-07-05 00:25:19.878258.json', 'station_status2022-07-05 18:5 ...

# %% [markdown]
#  ### Load each file from every 10 mins into a data frame and concatenate the df

# %%
# dir_list is the list of all the file names
# Creating a list of dataframe: for loops to go to the each name, open that file into a data frame and add it to the list (df_list.append(df_time))
# df_all is the concatanation of all the dataframe from the df_list


df_list = []
for name in dir_list:
    # Opening JSON file
    file = open(path+ '/' +name)
  
    # returns JSON object as 
    # a dictionary
    data_time = json.load(file)
    df_time = pd.DataFrame(data_time['data']['stations'])
    df_list.append(df_time)
    
df_all = pd.concat(df_list)

df_all.head()
# Out:
#    is_installed  is_renting  eightd_has_available_keys  num_docks_available  \
# 0             0           0                      False                   55
# 1             1           1                      False                    7
# 2             1           1                      False                    2
# 3             1           1                      False                    2
# 4             0           0                      False                    0
#
#    num_bikes_available  num_bikes_disabled  is_returning station_id  \
# 0                    0                   0             0         72
# 1                   22                   3             1         79
# 2                   24                   1             1         82
# 3                   60                   0             1         83
# 4                    0                   0             0        116
#
#    num_ebikes_available  station_status  num_docks_disabled  last_reported  \
# 0                     0  out_of_service                   0     1656077952
# 1                     0          active                   0     1657062379
# 2                     2          active                   0     1657062579
# 3                     0          active                   0     1657062783
# 4                     0  out_of_service                   0          86400
#
#   legacy_id eightd_active_station_services valet
# 0        72                            NaN   NaN
# 1        79                            NaN   NaN
# 2        82                            NaN   NaN
# 3        83                            NaN   NaN
# 4       116                            NaN   NaN

# %%
#check to see if we got all the files included in df_all - check with the station ID 72 as an example - looks fine
df_all.loc[pd.Index([72], name="station_id")]
# Out:
#             is_installed  is_renting  eightd_has_available_keys  \
# station_id
# 72                     1           1                      False
# 72                     1           1                      False
# 72                     1           1                      False
# 72                     1           1                      False
# 72                     1           1                      False
# ...                  ...         ...                        ...
# 72                     1           1                      False
# 72                     1           1                      False
# 72                     1           1                      False
# 72                     1           1                      False
# 72                     1           1                      False
#
#             num_docks_available  num_bikes_available  num_bikes_disabled  \
# station_id
# 72                            1                   25                   5
# 72                            1                   28                   2
# 72                            0                   29                   2
# 72                            3                   25                   3
# 72                            1                   26                   4
# ...                         ...                  ...                 ...
# 72                           10                   19                   2
# 72                            0                   29                   2
# 72                            6                   23                   2
# 72                           12                   16                   2
# 72                            0                   29                   2
#
#             is_returning station_id  num_ebikes_available station_status  \
# station_id
# 72                     1        307                     1         active
# 72                     1        307                     0         active
# 72                     1        307                     0         active
# 72                     1        307                     1         active
# 72                     1        307                     3         active
# ...                  ...        ...                   ...            ...
# 72                     1        307                     1         active
# 72                     1        307                     0         active
# 72                     1        307                     1         active
# 72                     1        307                     1         active
# 72                     1        307                     0         active
#
#             num_docks_disabled  last_reported legacy_id  \
# station_id
# 72                           0     1657062604       307
# 72                           0     1657020558       307
# 72                           0     1656998208       307
# 72                           0     1657075150       307
# 72                           0     1657053162       307
# ...                        ...            ...       ...
# 72                           0     1657036495       307
# 72                           0     1656998208       307
# 72                           0     1657037533       307
# 72                           0     1657029914       307
# 72                           0     1656998208       307
#
#            eightd_active_station_services valet
# station_id
# 72                                    NaN   NaN
# 72                                    NaN   NaN
# 72                                    NaN   NaN
# 72                                    NaN   NaN
# 72                                    NaN   NaN
# ...                                   ...   ...
# 72                                    NaN   NaN
# 72                                    NaN   NaN
# 72                                    NaN   NaN
# 72                                    NaN   NaN
# 72                                    NaN   NaN
#
# [156 rows x 15 columns]

# %%
#Change the format of ALL the last_reported (timestamp) to datetime

df_all['time'] = pd.to_datetime(df_all.last_reported, unit='s')
df_all.head()
# Out:
#    is_installed  is_renting  eightd_has_available_keys  num_docks_available  \
# 0             0           0                      False                   55
# 1             1           1                      False                    7
# 2             1           1                      False                    2
# 3             1           1                      False                    2
# 4             0           0                      False                    0
#
#    num_bikes_available  num_bikes_disabled  is_returning station_id  \
# 0                    0                   0             0         72
# 1                   22                   3             1         79
# 2                   24                   1             1         82
# 3                   60                   0             1         83
# 4                    0                   0             0        116
#
#    num_ebikes_available  station_status  num_docks_disabled  last_reported  \
# 0                     0  out_of_service                   0     1656077952
# 1                     0          active                   0     1657062379
# 2                     2          active                   0     1657062579
# 3                     0          active                   0     1657062783
# 4                     0  out_of_service                   0          86400
#
#   legacy_id eightd_active_station_services valet                time
# 0        72                            NaN   NaN 2022-06-24 13:39:12
# 1        79                            NaN   NaN 2022-07-05 23:06:19
# 2        82                            NaN   NaN 2022-07-05 23:09:39
# 3        83                            NaN   NaN 2022-07-05 23:13:03
# 4       116                            NaN   NaN 1970-01-02 00:00:00

# %%
df_all.shape
# Out:
# (264963, 16)

# %% [markdown]
# ### Clean up the data

# %%
#Drop the rows where station_status is out_of_service
df_all=df_all.loc[df_all["station_status"] != 'out_of_service']
df_all.head()
# Out:
#    is_installed  is_renting  eightd_has_available_keys  num_docks_available  \
# 1             1           1                      False                    7
# 2             1           1                      False                    2
# 3             1           1                      False                    2
# 5             1           1                      False                    0
# 6             1           1                      False                    1
#
#    num_bikes_available  num_bikes_disabled  is_returning station_id  \
# 1                   22                   3             1         79
# 2                   24                   1             1         82
# 3                   60                   0             1         83
# 5                   50                   3             1        119
# 6                   18                   0             1        120
#
#    num_ebikes_available station_status  num_docks_disabled  last_reported  \
# 1                     0         active                   0     1657062379
# 2                     2         active                   0     1657062579
# 3                     0         active                   0     1657062783
# 5                     0         active                   0     1657062401
# 6                     0         active                   0     1657062836
#
#   legacy_id eightd_active_station_services valet                time
# 1        79                            NaN   NaN 2022-07-05 23:06:19
# 2        82                            NaN   NaN 2022-07-05 23:09:39
# 3        83                            NaN   NaN 2022-07-05 23:13:03
# 5       119                            NaN   NaN 2022-07-05 23:06:41
# 6       120                            NaN   NaN 2022-07-05 23:13:56

# %%
#check if they were dropped
df_all.shape
# Out:
# (252881, 16)

# %%
#Drop all the unnecessary columns 
df_all= df_all.drop(['num_bikes_disabled','num_docks_disabled','is_renting','eightd_has_available_keys','is_returning', 'legacy_id', 'is_installed', 'eightd_active_station_services', 'valet'], axis=1)

# %%
df_all.head()
# Out:
#    num_docks_available  num_bikes_available station_id  num_ebikes_available  \
# 1                    7                   22         79                     0
# 2                    2                   24         82                     2
# 3                    2                   60         83                     0
# 5                    0                   50        119                     0
# 6                    1                   18        120                     0
#
#   station_status  last_reported                time
# 1         active     1657062379 2022-07-05 23:06:19
# 2         active     1657062579 2022-07-05 23:09:39
# 3         active     1657062783 2022-07-05 23:13:03
# 5         active     1657062401 2022-07-05 23:06:41
# 6         active     1657062836 2022-07-05 23:13:56

# %%
#check all the stations are active
df_all[df_all.station_status == 'active']
len(df_all.station_status == 'active')
# Out:
# 252881

# %%
# Create a new columns showing the total docks in each station
df_all['total_docks'] = df_all['num_docks_available'] + df_all ['num_bikes_available'] + df_all ['num_ebikes_available']
df_all.head()
# Out:
#    num_docks_available  num_bikes_available station_id  num_ebikes_available  \
# 1                    7                   22         79                     0
# 2                    2                   24         82                     2
# 3                    2                   60         83                     0
# 5                    0                   50        119                     0
# 6                    1                   18        120                     0
#
#   station_status  last_reported                time  total_docks
# 1         active     1657062379 2022-07-05 23:06:19           29
# 2         active     1657062579 2022-07-05 23:09:39           28
# 3         active     1657062783 2022-07-05 23:13:03           62
# 5         active     1657062401 2022-07-05 23:06:41           50
# 6         active     1657062836 2022-07-05 23:13:56           19

# %%
# Create a new columns showing the percentage of docks available
df_all['per_num_docks_available'] = (df_all['num_docks_available']/df_all['total_docks']*100)
df_all.head()
# Out:
#    num_docks_available  num_bikes_available station_id  num_ebikes_available  \
# 1                    7                   22         79                     0
# 2                    2                   24         82                     2
# 3                    2                   60         83                     0
# 5                    0                   50        119                     0
# 6                    1                   18        120                     0
#
#   station_status  last_reported                time  total_docks  \
# 1         active     1657062379 2022-07-05 23:06:19           29
# 2         active     1657062579 2022-07-05 23:09:39           28
# 3         active     1657062783 2022-07-05 23:13:03           62
# 5         active     1657062401 2022-07-05 23:06:41           50
# 6         active     1657062836 2022-07-05 23:13:56           19
#
#    per_num_docks_available
# 1                24.137931
# 2                 7.142857
# 3                 3.225806
# 5                 0.000000
# 6                 5.263158

# %%
# Create a new columns showing the percentage of normal bikes (not the ebikes) available
df_all['per_num_bikes_available'] = (df_all['num_bikes_available']/df_all['total_docks']*100)
df_all.head()
# Out:
#    num_docks_available  num_bikes_available station_id  num_ebikes_available  \
# 1                    7                   22         79                     0
# 2                    2                   24         82                     2
# 3                    2                   60         83                     0
# 5                    0                   50        119                     0
# 6                    1                   18        120                     0
#
#   station_status  last_reported                time  total_docks  \
# 1         active     1657062379 2022-07-05 23:06:19           29
# 2         active     1657062579 2022-07-05 23:09:39           28
# 3         active     1657062783 2022-07-05 23:13:03           62
# 5         active     1657062401 2022-07-05 23:06:41           50
# 6         active     1657062836 2022-07-05 23:13:56           19
#
#    per_num_docks_available  per_num_bikes_available
# 1                24.137931                75.862069
# 2                 7.142857                85.714286
# 3                 3.225806                96.774194
# 5                 0.000000               100.000000
# 6                 5.263158                94.736842

# %%
#sort by time
df_all = df_all.sort_values(by='time')
df_all
# Out:
#       num_docks_available  num_bikes_available station_id  \
# 635                     0                    0       3553
# 1334                    0                    0       4407
# 415                     0                    0       3267
# 1334                    0                    0       4407
# 1386                    0                    0       4466
# ...                   ...                  ...        ...
# 34                      2                   46        244
# 1467                   10                    2       4559
# 798                     0                   19       3795
# 653                     5                   15       3574
# 1526                    2                   52       4625
#
#       num_ebikes_available station_status  last_reported                time  \
# 635                      0         active          86400 1970-01-02 00:00:00
# 1334                     0         active          86400 1970-01-02 00:00:00
# 415                      0         active          86400 1970-01-02 00:00:00
# 1334                     0         active          86400 1970-01-02 00:00:00
# 1386                     0         active          86400 1970-01-02 00:00:00
# ...                    ...            ...            ...                 ...
# 34                       0         active     1657079740 2022-07-06 03:55:40
# 1467                     1         active     1657079740 2022-07-06 03:55:40
# 798                      2         active     1657079742 2022-07-06 03:55:42
# 653                      4         active     1657079742 2022-07-06 03:55:42
# 1526                     1         active     1657079743 2022-07-06 03:55:43
#
#       total_docks  per_num_docks_available  per_num_bikes_available
# 635             0                      NaN                      NaN
# 1334            0                      NaN                      NaN
# 415             0                      NaN                      NaN
# 1334            0                      NaN                      NaN
# 1386            0                      NaN                      NaN
# ...           ...                      ...                      ...
# 34             48                 4.166667                95.833333
# 1467           13                76.923077                15.384615
# 798            21                 0.000000                90.476190
# 653            24                20.833333                62.500000
# 1526           55                 3.636364                94.545455
#
# [252881 rows x 10 columns]

# %%
#Drop all the stations where total_docks are 0 (because the time says 1970)
df_all=df_all.loc[df_all["total_docks"] !=0]
df_all.shape
# Out:
# (248710, 10)

# %% [markdown]
# # Merge with the Station Information file "Zip_and_total_Capacity" using the station ID to add the zipcode and station address to this data frame

# %%
#load the CSV file from the station information with zipcode and adress
df_capacity = pd.read_csv("Zip_and_total_Capacity.csv")
df_capacity.head()
# Out:
#                                 name        lon  has_kiosk  station_id  \
# 0                   W 52 St & 11 Ave -73.993929       True          72
# 1  Grand Army Plaza & Central Park S -73.973715       True         281
# 2                    W 56 St & 6 Ave -73.977225       True         352
# 3                   W 59 St & 10 Ave -73.988038       True         422
# 4                    W 54 St & 9 Ave -73.986905       True         423
#
#   eightd_station_services station_type        lat  region_id  \
# 0                      []      classic  40.767272         71
# 1                      []      classic  40.764397         71
# 2                      []      classic  40.763406         71
# 3                      []      classic  40.770513         71
# 4                      []      classic  40.765849         71
#
#    capacity_original  zipCode  capacity_zip_sum
# 0                 55    10019              1510
# 1                 96    10019              1510
# 2                 36    10019              1510
# 3                115    10019              1510
# 4                 44    10019              1510

# %%
#drop the unnecessary column
df_capacity= df_capacity.drop(['eightd_station_services'], axis=1)

# %%
df_capacity.head()
# Out:
#                                 name        lon  has_kiosk  station_id  \
# 0                   W 52 St & 11 Ave -73.993929       True          72
# 1  Grand Army Plaza & Central Park S -73.973715       True         281
# 2                    W 56 St & 6 Ave -73.977225       True         352
# 3                   W 59 St & 10 Ave -73.988038       True         422
# 4                    W 54 St & 9 Ave -73.986905       True         423
#
#   station_type        lat  region_id  capacity_original  zipCode  \
# 0      classic  40.767272         71                 55    10019
# 1      classic  40.764397         71                 96    10019
# 2      classic  40.763406         71                 36    10019
# 3      classic  40.770513         71                115    10019
# 4      classic  40.765849         71                 44    10019
#
#    capacity_zip_sum
# 0              1510
# 1              1510
# 2              1510
# 3              1510
# 4              1510

# %%
# in order to merge two files using the station id, station id needs to be the same data time in both file - so check that first
df_all.dtypes
# Out:
# num_docks_available                 int64
# num_bikes_available                 int64
# station_id                          int64
# num_ebikes_available                int64
# station_status                     object
# last_reported                       int64
# time                       datetime64[ns]
# total_docks                         int64
# per_num_docks_available           float64
# per_num_bikes_available           float64
# dtype: object

# %%
df_capacity.dtypes
# Out:
# name                  object
# lon                  float64
# has_kiosk               bool
# station_id             int64
# station_type          object
# lat                  float64
# region_id              int64
# capacity_original      int64
# zipCode                int64
# capacity_zip_sum       int64
# dtype: object

# %%
df_all["station_id"] = df_all["station_id"].astype(str).astype(int)
# Out:
# /var/folders/dd/g69lxp4x1djctd176xmjplxh0000gp/T/ipykernel_31809/847696470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["station_id"] = df_all["station_id"].astype(str).astype(int)

# %%
df_all.dtypes
# Out:
# num_docks_available                 int64
# num_bikes_available                 int64
# station_id                          int64
# num_ebikes_available                int64
# station_status                     object
# last_reported                       int64
# time                       datetime64[ns]
# total_docks                         int64
# per_num_docks_available           float64
# per_num_bikes_available           float64
# dtype: object

# %%
#df_total to include everything by merging station information (zip and address) and station status (live data)
df_total = df_all.merge(df_capacity,
         left_on='station_id',
         right_on='station_id',
         suffixes=('_x', '_y'))

# %%
df_total.head()
# Out:
#    num_docks_available  num_bikes_available  station_id  num_ebikes_available  \
# 0                    1                   66         477                    36
# 1                    1                   67         477                    37
# 2                    1                   67         477                    37
# 3                    1                   67         477                    37
# 4                    1                   67         477                    37
#
#   station_status  last_reported                time  total_docks  \
# 0         active     1656674875 2022-07-01 11:27:55          103
# 1         active     1656674875 2022-07-01 11:27:55          105
# 2         active     1656674875 2022-07-01 11:27:55          105
# 3         active     1656674875 2022-07-01 11:27:55          105
# 4         active     1656674875 2022-07-01 11:27:55          105
#
#    per_num_docks_available  per_num_bikes_available             name  \
# 0                 0.970874                64.077670  W 41 St & 8 Ave
# 1                 0.952381                63.809524  W 41 St & 8 Ave
# 2                 0.952381                63.809524  W 41 St & 8 Ave
# 3                 0.952381                63.809524  W 41 St & 8 Ave
# 4                 0.952381                63.809524  W 41 St & 8 Ave
#
#          lon  has_kiosk station_type        lat  region_id  capacity_original  \
# 0 -73.990026       True      classic  40.756405         71                 71
# 1 -73.990026       True      classic  40.756405         71                 71
# 2 -73.990026       True      classic  40.756405         71                 71
# 3 -73.990026       True      classic  40.756405         71                 71
# 4 -73.990026       True      classic  40.756405         71                 71
#
#    zipCode  capacity_zip_sum
# 0    10018               746
# 1    10018               746
# 2    10018               746
# 3    10018               746
# 4    10018               746

# %%
df_total.shape
# Out:
# (236543, 19)

# %%
#Drop all the duplicate rows
df_total = df_total.drop_duplicates()

# %%
df_total.shape
# Out:
# (86550, 19)

# %%
#Try filtering only one station to test if it worked - try the station ID 531
df_total.query("station_id == 531")
# Out:
#         num_docks_available  num_bikes_available  station_id  \
# 194680                    0                   64         531
# 194690                    0                   64         531
# 194715                    1                   63         531
# 194717                    0                   64         531
# 194729                    0                   64         531
# ...                     ...                  ...         ...
# 194820                    9                   57         531
# 194822                    6                   60         531
# 194823                    5                   61         531
# 194824                    7                   59         531
# 194829                    6                   60         531
#
#         num_ebikes_available station_status  last_reported  \
# 194680                     0         active     1656993737
# 194690                     0         active     1656998208
# 194715                     0         active     1657012275
# 194717                     0         active     1657013183
# 194729                     0         active     1657020486
# ...                      ...            ...            ...
# 194820                     0         active     1657072808
# 194822                     1         active     1657074229
# 194823                     1         active     1657074827
# 194824                     0         active     1657075146
# 194829                     0         active     1657077148
#
#                       time  total_docks  per_num_docks_available  \
# 194680 2022-07-05 04:02:17           64                 0.000000
# 194690 2022-07-05 05:16:48           64                 0.000000
# 194715 2022-07-05 09:11:15           64                 1.562500
# 194717 2022-07-05 09:26:23           64                 0.000000
# 194729 2022-07-05 11:28:06           64                 0.000000
# ...                    ...          ...                      ...
# 194820 2022-07-06 02:00:08           66                13.636364
# 194822 2022-07-06 02:23:49           67                 8.955224
# 194823 2022-07-06 02:33:47           67                 7.462687
# 194824 2022-07-06 02:39:06           66                10.606061
# 194829 2022-07-06 03:12:28           66                 9.090909
#
#         per_num_bikes_available                    name        lon  has_kiosk  \
# 194680               100.000000  Forsyth St & Broome St -73.992663       True
# 194690               100.000000  Forsyth St & Broome St -73.992663       True
# 194715                98.437500  Forsyth St & Broome St -73.992663       True
# 194717               100.000000  Forsyth St & Broome St -73.992663       True
# 194729               100.000000  Forsyth St & Broome St -73.992663       True
# ...                         ...                     ...        ...        ...
# 194820                86.363636  Forsyth St & Broome St -73.992663       True
# 194822                89.552239  Forsyth St & Broome St -73.992663       True
# 194823                91.044776  Forsyth St & Broome St -73.992663       True
# 194824                89.393939  Forsyth St & Broome St -73.992663       True
# 194829                90.909091  Forsyth St & Broome St -73.992663       True
#
#        station_type        lat  region_id  capacity_original  zipCode  \
# 194680      classic  40.718939         71                 66    10002
# 194690      classic  40.718939         71                 66    10002
# 194715      classic  40.718939         71                 66    10002
# 194717      classic  40.718939         71                 66    10002
# 194729      classic  40.718939         71                 66    10002
# ...             ...        ...        ...                ...      ...
# 194820      classic  40.718939         71                 66    10002
# 194822      classic  40.718939         71                 66    10002
# 194823      classic  40.718939         71                 66    10002
# 194824      classic  40.718939         71                 66    10002
# 194829      classic  40.718939         71                 66    10002
#
#         capacity_zip_sum
# 194680              1349
# 194690              1349
# 194715              1349
# 194717              1349
# 194729              1349
# ...                  ...
# 194820              1349
# 194822              1349
# 194823              1349
# 194824              1349
# 194829              1349
#
# [68 rows x 19 columns]

# %% [markdown]
# # Any noticable trends?

# %%
# Which station has the most bike capacities?
df_total.total_docks.max()
# Out:
# 121

# %%
# Ok, I'll focus on this most popular station as a visualization!!!
df_total.query("total_docks == 121")
# Out:
#         num_docks_available  num_bikes_available  station_id  \
# 189344                  102                   13         422
# 189355                   97                   17         422
# 189357                   93                   21         422
#
#         num_ebikes_available station_status  last_reported  \
# 189344                     6         active     1657062314
# 189355                     7         active     1657069735
# 189357                     7         active     1657071182
#
#                       time  total_docks  per_num_docks_available  \
# 189344 2022-07-05 23:05:14          121                84.297521
# 189355 2022-07-06 01:08:55          121                80.165289
# 189357 2022-07-06 01:33:02          121                76.859504
#
#         per_num_bikes_available              name        lon  has_kiosk  \
# 189344                10.743802  W 59 St & 10 Ave -73.988038       True
# 189355                14.049587  W 59 St & 10 Ave -73.988038       True
# 189357                17.355372  W 59 St & 10 Ave -73.988038       True
#
#        station_type        lat  region_id  capacity_original  zipCode  \
# 189344      classic  40.770513         71                115    10019
# 189355      classic  40.770513         71                115    10019
# 189357      classic  40.770513         71                115    10019
#
#         capacity_zip_sum
# 189344              1510
# 189355              1510
# 189357              1510

# %%
# Station ID 422 in midtown has the highest numbers of bike available
# Sort by time to visualize the capacity by time
df_total.sort_values(by='time', ascending = False).query("station_id == 422")
# Out:
#         num_docks_available  num_bikes_available  station_id  \
# 189374                   83                   30         422
# 189373                   84                   29         422
# 189372                   83                   30         422
# 189370                   82                   31         422
# 189369                   84                   29         422
# ...                     ...                  ...         ...
# 189224                   97                   18         422
# 189223                   97                   18         422
# 189222                   97                   17         422
# 189221                   98                   16         422
# 189220                   98                   15         422
#
#         num_ebikes_available station_status  last_reported  \
# 189374                     3         active     1657078745
# 189373                     2         active     1657078024
# 189372                     2         active     1657077680
# 189370                     3         active     1657077528
# 189369                     4         active     1657077320
# ...                      ...            ...            ...
# 189224                     3         active     1656995999
# 189223                     2         active     1656994818
# 189222                     1         active     1656994818
# 189221                     2         active     1656993709
# 189220                     1         active     1656993709
#
#                       time  total_docks  per_num_docks_available  \
# 189374 2022-07-06 03:39:05          116                71.551724
# 189373 2022-07-06 03:27:04          115                73.043478
# 189372 2022-07-06 03:21:20          115                72.173913
# 189370 2022-07-06 03:18:48          116                70.689655
# 189369 2022-07-06 03:15:20          117                71.794872
# ...                    ...          ...                      ...
# 189224 2022-07-05 04:39:59          118                82.203390
# 189223 2022-07-05 04:20:18          117                82.905983
# 189222 2022-07-05 04:20:18          115                84.347826
# 189221 2022-07-05 04:01:49          116                84.482759
# 189220 2022-07-05 04:01:49          114                85.964912
#
#         per_num_bikes_available              name        lon  has_kiosk  \
# 189374                25.862069  W 59 St & 10 Ave -73.988038       True
# 189373                25.217391  W 59 St & 10 Ave -73.988038       True
# 189372                26.086957  W 59 St & 10 Ave -73.988038       True
# 189370                26.724138  W 59 St & 10 Ave -73.988038       True
# 189369                24.786325  W 59 St & 10 Ave -73.988038       True
# ...                         ...               ...        ...        ...
# 189224                15.254237  W 59 St & 10 Ave -73.988038       True
# 189223                15.384615  W 59 St & 10 Ave -73.988038       True
# 189222                14.782609  W 59 St & 10 Ave -73.988038       True
# 189221                13.793103  W 59 St & 10 Ave -73.988038       True
# 189220                13.157895  W 59 St & 10 Ave -73.988038       True
#
#        station_type        lat  region_id  capacity_original  zipCode  \
# 189374      classic  40.770513         71                115    10019
# 189373      classic  40.770513         71                115    10019
# 189372      classic  40.770513         71                115    10019
# 189370      classic  40.770513         71                115    10019
# 189369      classic  40.770513         71                115    10019
# ...             ...        ...        ...                ...      ...
# 189224      classic  40.770513         71                115    10019
# 189223      classic  40.770513         71                115    10019
# 189222      classic  40.770513         71                115    10019
# 189221      classic  40.770513         71                115    10019
# 189220      classic  40.770513         71                115    10019
#
#         capacity_zip_sum
# 189374              1510
# 189373              1510
# 189372              1510
# 189370              1510
# 189369              1510
# ...                  ...
# 189224              1510
# 189223              1510
# 189222              1510
# 189221              1510
# 189220              1510
#
# [108 rows x 19 columns]

# %%
# Just checking
df_total.sort_values(by='total_docks', ascending = False)
# Out:
#         num_docks_available  num_bikes_available  station_id  \
# 189355                   97                   17         422
# 189357                   93                   21         422
# 189344                  102                   13         422
# 189345                  100                   14         422
# 189354                   99                   15         422
# ...                     ...                  ...         ...
# 328                       1                    0        3119
# 381                       1                    0        3119
# 410                       1                    0        3119
# 235296                    0                    1        3150
# 235299                    0                    1        3150
#
#         num_ebikes_available station_status  last_reported  \
# 189355                     7         active     1657069735
# 189357                     7         active     1657071182
# 189344                     6         active     1657062314
# 189345                     6         active     1657062651
# 189354                     5         active     1657069518
# ...                      ...            ...            ...
# 328                        0         active     1657000637
# 381                        0         active     1657032524
# 410                        0         active     1657049132
# 235296                     0         active     1657008068
# 235299                     0         active     1657016550
#
#                       time  total_docks  per_num_docks_available  \
# 189355 2022-07-06 01:08:55          121                80.165289
# 189357 2022-07-06 01:33:02          121                76.859504
# 189344 2022-07-05 23:05:14          121                84.297521
# 189345 2022-07-05 23:10:51          120                83.333333
# 189354 2022-07-06 01:05:18          119                83.193277
# ...                    ...          ...                      ...
# 328    2022-07-05 05:57:17            1               100.000000
# 381    2022-07-05 14:48:44            1               100.000000
# 410    2022-07-05 19:25:32            1               100.000000
# 235296 2022-07-05 08:01:08            1                 0.000000
# 235299 2022-07-05 10:22:30            1                 0.000000
#
#         per_num_bikes_available                  name        lon  has_kiosk  \
# 189355                14.049587      W 59 St & 10 Ave -73.988038       True
# 189357                17.355372      W 59 St & 10 Ave -73.988038       True
# 189344                10.743802      W 59 St & 10 Ave -73.988038       True
# 189345                11.666667      W 59 St & 10 Ave -73.988038       True
# 189354                12.605042      W 59 St & 10 Ave -73.988038       True
# ...                         ...                   ...        ...        ...
# 328                    0.000000  Vernon Blvd & 50 Ave -73.954117       True
# 381                    0.000000  Vernon Blvd & 50 Ave -73.954117       True
# 410                    0.000000  Vernon Blvd & 50 Ave -73.954117       True
# 235296               100.000000    E 85 St & York Ave -73.948034       True
# 235299               100.000000    E 85 St & York Ave -73.948034       True
#
#        station_type        lat  region_id  capacity_original  zipCode  \
# 189355      classic  40.770513         71                115    10019
# 189357      classic  40.770513         71                115    10019
# 189344      classic  40.770513         71                115    10019
# 189345      classic  40.770513         71                115    10019
# 189354      classic  40.770513         71                115    10019
# ...             ...        ...        ...                ...      ...
# 328         classic  40.742327         71                 45    11101
# 381         classic  40.742327         71                 45    11101
# 410         classic  40.742327         71                 45    11101
# 235296      classic  40.775369         71                 47    10028
# 235299      classic  40.775369         71                 47    10028
#
#         capacity_zip_sum
# 189355              1510
# 189357              1510
# 189344              1510
# 189345              1510
# 189354              1510
# ...                  ...
# 328                 1531
# 381                 1531
# 410                 1531
# 235296               392
# 235299               392
#
# [86550 rows x 19 columns]

# %%
#Average number of bike capacity
df_total.total_docks.mean()
# Out:
# 35.631704217215486

# %% [markdown]
# # Save the master file

# %%
#Save the CSV file for ALL the station status
df_total.to_csv('Station_Status_Master.csv', index = False)

# %% [markdown]
# # Analyze the most popular station

# %%
#Highest bike capacity - the most popular
df_station422 = df_total.sort_values(by='time', ascending = False).query("station_id == 422")

# %%
df_station422 = df_station422.drop(['station_status', 'last_reported', 'lon', 'has_kiosk', 'station_type', 'lat', 'region_id' ], axis=1)

# %%
#Save the CSV file for the station 422 
df_station422.to_csv('station422.csv', index = False)

# %% [markdown]
# # Let's see if I find anything else interesting..

# %%
#Any other interesting stations?
#Try filtering only for zipcode 10027 of Columbia University
df_Columbia_Station = df_total.query("zipCode == 10027")
df_Columbia_Station.head()
# Out:
#        num_docks_available  num_bikes_available  station_id  \
# 13409                   18                    2        4104
# 13413                   17                    3        4104
# 13422                   18                    2        4104
# 13425                   17                    3        4104
# 13435                   17                    3        4104
#
#        num_ebikes_available station_status  last_reported                time  \
# 13409                     0         active     1656981200 2022-07-05 00:33:20
# 13413                     1         active     1656996205 2022-07-05 04:43:25
# 13422                     0         active     1656999228 2022-07-05 05:33:48
# 13425                     1         active     1657000998 2022-07-05 06:03:18
# 13435                     1         active     1657006708 2022-07-05 07:38:28
#
#        total_docks  per_num_docks_available  per_num_bikes_available  \
# 13409           20                90.000000                10.000000
# 13413           21                80.952381                14.285714
# 13422           20                90.000000                10.000000
# 13425           21                80.952381                14.285714
# 13435           21                80.952381                14.285714
#
#                           name        lon  has_kiosk station_type        lat  \
# 13409  Old Broadway & W 133 St -73.955277       True      classic  40.818212
# 13413  Old Broadway & W 133 St -73.955277       True      classic  40.818212
# 13422  Old Broadway & W 133 St -73.955277       True      classic  40.818212
# 13425  Old Broadway & W 133 St -73.955277       True      classic  40.818212
# 13435  Old Broadway & W 133 St -73.955277       True      classic  40.818212
#
#        region_id  capacity_original  zipCode  capacity_zip_sum
# 13409         71                 20    10027               668
# 13413         71                 20    10027               668
# 13422         71                 20    10027               668
# 13425         71                 20    10027               668
# 13435         71                 20    10027               668

# %%
#a citibike station near Columbia on W 116 St & Broadway
df_Columbia_Station_broadway = df_total.query("station_id == 3536")
df_Columbia_Station_broadway.head()
# Out:
#         num_docks_available  num_bikes_available  station_id  \
# 225465                   42                    0        3536
# 225468                   41                    1        3536
# 225485                   41                    1        3536
# 225519                   41                    1        3536
# 225521                   41                    1        3536
#
#         num_ebikes_available station_status  last_reported  \
# 225465                     0         active     1656993881
# 225468                     0         active     1656995313
# 225485                     0         active     1657003064
# 225519                     0         active     1657023900
# 225521                     0         active     1657024951
#
#                       time  total_docks  per_num_docks_available  \
# 225465 2022-07-05 04:04:41           42               100.000000
# 225468 2022-07-05 04:28:33           42                97.619048
# 225485 2022-07-05 06:37:44           42                97.619048
# 225519 2022-07-05 12:25:00           42                97.619048
# 225521 2022-07-05 12:42:31           42                97.619048
#
#         per_num_bikes_available                 name      lon  has_kiosk  \
# 225465                 0.000000  W 116 St & Broadway -73.9641       True
# 225468                 2.380952  W 116 St & Broadway -73.9641       True
# 225485                 2.380952  W 116 St & Broadway -73.9641       True
# 225519                 2.380952  W 116 St & Broadway -73.9641       True
# 225521                 2.380952  W 116 St & Broadway -73.9641       True
#
#        station_type      lat  region_id  capacity_original  zipCode  \
# 225465      classic  40.8082         71                 43    10027
# 225468      classic  40.8082         71                 43    10027
# 225485      classic  40.8082         71                 43    10027
# 225519      classic  40.8082         71                 43    10027
# 225521      classic  40.8082         71                 43    10027
#
#         capacity_zip_sum
# 225465               668
# 225468               668
# 225485               668
# 225519               668
# 225521               668

# %%
df_Columbia_Station_broadway= df_Columbia_Station_broadway.drop(['station_status', 'last_reported', 'lon', 'has_kiosk', 'station_type', 'lat', 'region_id' ], axis=1)

# %%
df_Columbia_Station_broadway.head()
# Out:
#         num_docks_available  num_bikes_available  station_id  \
# 225465                   42                    0        3536
# 225468                   41                    1        3536
# 225485                   41                    1        3536
# 225519                   41                    1        3536
# 225521                   41                    1        3536
#
#         num_ebikes_available                time  total_docks  \
# 225465                     0 2022-07-05 04:04:41           42
# 225468                     0 2022-07-05 04:28:33           42
# 225485                     0 2022-07-05 06:37:44           42
# 225519                     0 2022-07-05 12:25:00           42
# 225521                     0 2022-07-05 12:42:31           42
#
#         per_num_docks_available  per_num_bikes_available                 name  \
# 225465               100.000000                 0.000000  W 116 St & Broadway
# 225468                97.619048                 2.380952  W 116 St & Broadway
# 225485                97.619048                 2.380952  W 116 St & Broadway
# 225519                97.619048                 2.380952  W 116 St & Broadway
# 225521                97.619048                 2.380952  W 116 St & Broadway
#
#         capacity_original  zipCode  capacity_zip_sum
# 225465                 43    10027               668
# 225468                 43    10027               668
# 225485                 43    10027               668
# 225519                 43    10027               668
# 225521                 43    10027               668

# %%
#Save the CSV file for Columbia_Station_broadway
df_Columbia_Station_broadway.to_csv('Columbia_Station_broadway.csv', index = False)

# %%
#a citibike station near Columbia on W 116 St & Amsterdam Ave
df_Columbia_Station_amsterdam = df_total.query("station_id == 3539")
df_Columbia_Station_amsterdam.head()
# Out:
#        num_docks_available  num_bikes_available  station_id  \
# 68768                   29                    1        3539
# 68789                   30                    0        3539
# 68790                   30                    0        3539
# 68806                   31                    0        3539
# 68807                   30                    1        3539
#
#        num_ebikes_available station_status  last_reported                time  \
# 68768                     0         active     1656991327 2022-07-05 03:22:07
# 68789                     0         active     1657003939 2022-07-05 06:52:19
# 68790                     0         active     1657004278 2022-07-05 06:57:58
# 68806                     0         active     1657014261 2022-07-05 09:44:21
# 68807                     1         active     1657014539 2022-07-05 09:48:59
#
#        total_docks  per_num_docks_available  per_num_bikes_available  \
# 68768           30                96.666667                 3.333333
# 68789           30               100.000000                 0.000000
# 68790           30               100.000000                 0.000000
# 68806           31               100.000000                 0.000000
# 68807           32                93.750000                 3.125000
#
#                            name        lon  has_kiosk station_type        lat  \
# 68768  W 116 St & Amsterdam Ave -73.960708       True      classic  40.806758
# 68789  W 116 St & Amsterdam Ave -73.960708       True      classic  40.806758
# 68790  W 116 St & Amsterdam Ave -73.960708       True      classic  40.806758
# 68806  W 116 St & Amsterdam Ave -73.960708       True      classic  40.806758
# 68807  W 116 St & Amsterdam Ave -73.960708       True      classic  40.806758
#
#        region_id  capacity_original  zipCode  capacity_zip_sum
# 68768         71                 43    10027               668
# 68789         71                 43    10027               668
# 68790         71                 43    10027               668
# 68806         71                 43    10027               668
# 68807         71                 43    10027               668

# %%
df_Columbia_Station_amsterdam.head()

# %%
#Save the CSV file for Columbia_Station_broadway
df_Columbia_Station_amsterdam.to_csv('Columbia_Station_amsterdam.csv', index = False)

# %%
#group by time for the percentage of bike available 
per_bike = df_total.groupby('time').per_num_bikes_available.mean()
per_bike

# %%
#Merge 
df_per_bike = df_total.merge(per_bike,
         left_on='time',
         right_index=True,
         suffixes=('_original', '_per_bike'))

# %%
df_per_bike

# %%
#Save the csv
df_per_bike.to_csv('Per_bike_bytime.csv', index = False)

# %%
df_bike_per_time = pd.read_csv('Per_bike_bytime.csv')
df_bike_per_time.head()

# %%
df_bike_per_time.= df_bike_per_time.drop(['num_docks_available','num_bikes_available','station_id','num_ebikes_available','station_status','last_reported','total_docks','per_num_docks_available','name','lon','has_kiosk','station_type','lat','region_id','capacity_original','zipCode','capacity_zip_sum'], axis=1)

# %%
df_capa_zip = pd.read_csv("Station_Capacity_by_Zip.csv")
df_capa_zip = df_capa_zip.drop_duplicates()

# %%
df_capa_zip.to_csv('Capacity_by_zip.csv', index = False)

# %%
#Save the CSV file for the station status near Columbia University
df_Columbia_Station.to_csv('Station_Status_Columbia.csv', index = False)
