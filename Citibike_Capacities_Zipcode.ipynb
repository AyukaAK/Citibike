# %% [markdown]
# # Analyzing the live citibike station data
#
# ## 1. Save the citibike capcity from July 3 - just once because it doesn't change that often
# ## 2. using google map API, convert the geo cordinate into the zipcode
#
# #### Station information as of July 3, 2022

# %% [markdown]
# #### Set up: Import/install all the necessary things

# %%
import requests
import pandas as pd

# %%
#Import Googlemap
import googlemaps

# %%
pip install -U googlemaps
# Out:
# Requirement already satisfied: googlemaps in /Users/ayukakawakami/.pyenv/versions/3.10.3/lib/python3.10/site-packages (4.6.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/ayukakawakami/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from googlemaps) (2.28.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/ayukakawakami/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayukakawakami/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayukakawakami/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ayukakawakami/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.9)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/ayukakawakami/.pyenv/versions/3.10.3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#Google map API key = AIzaSyDOSsHpaWdkEV5K8CytXP4D3tBAcPN7wJQ

# %%
#Citi bike station data as of July 3, 2022
url_capacities = "https://gbfs.citibikenyc.com/gbfs/en/station_information.json"

# %%
response = requests.get (url_capacities)
data = response.json()

# %% [markdown]
# #### Check the Citibike station information json data

# %%
print (data)
# Out:
# {'data': {'stations': [{'lat': 40.76727216, 'name': 'W 52 St & 11 Ave', 'external_id': '66db237e-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '72', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 55, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '72', 'short_name': '6926.01', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.99392888}, {'lat': 40.71911552, 'name': 'Franklin St & W Broadway', 'external_id': '66db269c-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '79', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 33, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '79', 'short_name': '5430.08', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -74.00666661}, {'lat': 40.71117416, 'name': 'St James Pl & Pearl St', 'external_id': '66db277a-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '82', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 27, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '82', 'short_name': '5167.06', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -74.00016545}, {'lat': 40.68382604, 'name': 'Atlantic Ave & Fort Greene Pl', 'external_id': '66db281e-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '83', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 62, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '83', 'short_name': '4354.07', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.97632328}, {'lat': 40.74177603, 'name': 'W 17 St & 8 Ave', 'external_id': '66db28b5-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '116', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 0, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '116', 'short_name': '6148.02', 'has_kiosk': False, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -74.00149746}, {'lat': 40.69608941, 'name': 'Park Ave & St Edwards St', 'external_id': '66db2953-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '119', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 53, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '119', 'short_name': '4700.06', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.97803415}, {'lat': 40.68676793, 'name': 'Lexington Ave & Classon Ave', 'external_id': '66db29e6-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '120', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 19, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '120', 'short_name': '4452.03', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.95928168}, {'lat': 40.73172428, 'name': 'Barrow St & Hudson St', 'external_id': '66db2a71-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '127', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/las ...

# %%
print(data.keys())
print(data['data']['stations'])
# Out:
# dict_keys(['data', 'last_updated', 'ttl'])
# [{'lat': 40.76727216, 'name': 'W 52 St & 11 Ave', 'external_id': '66db237e-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '72', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 55, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '72', 'short_name': '6926.01', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.99392888}, {'lat': 40.71911552, 'name': 'Franklin St & W Broadway', 'external_id': '66db269c-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '79', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 33, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '79', 'short_name': '5430.08', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -74.00666661}, {'lat': 40.71117416, 'name': 'St James Pl & Pearl St', 'external_id': '66db277a-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '82', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 27, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '82', 'short_name': '5167.06', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -74.00016545}, {'lat': 40.68382604, 'name': 'Atlantic Ave & Fort Greene Pl', 'external_id': '66db281e-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '83', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 62, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '83', 'short_name': '4354.07', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.97632328}, {'lat': 40.74177603, 'name': 'W 17 St & 8 Ave', 'external_id': '66db28b5-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '116', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 0, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '116', 'short_name': '6148.02', 'has_kiosk': False, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -74.00149746}, {'lat': 40.69608941, 'name': 'Park Ave & St Edwards St', 'external_id': '66db2953-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '119', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 53, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '119', 'short_name': '4700.06', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.97803415}, {'lat': 40.68676793, 'name': 'Lexington Ave & Classon Ave', 'external_id': '66db29e6-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '120', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'android': 'https://bkn.lft.to/lastmile_qr_scan'}, 'capacity': 19, 'electric_bike_surcharge_waiver': False, 'rental_methods': ['KEY', 'CREDITCARD'], 'station_id': '120', 'short_name': '4452.03', 'has_kiosk': True, 'eightd_station_services': [], 'region_id': '71', 'eightd_has_key_dispenser': False, 'lon': -73.95928168}, {'lat': 40.73172428, 'name': 'Barrow St & Hudson St', 'external_id': '66db2a71-0aca-11e7-82f6-3863bb44ef7c', 'legacy_id': '127', 'station_type': 'classic', 'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan', 'andro ...

# %%
df = pd.DataFrame(data['data']['stations'])
df.head()
# Out:
#          lat                           name  \
# 0  40.767272               W 52 St & 11 Ave
# 1  40.719116       Franklin St & W Broadway
# 2  40.711174         St James Pl & Pearl St
# 3  40.683826  Atlantic Ave & Fort Greene Pl
# 4  40.741776                W 17 St & 8 Ave
#
#                             external_id legacy_id station_type  \
# 0  66db237e-0aca-11e7-82f6-3863bb44ef7c        72      classic
# 1  66db269c-0aca-11e7-82f6-3863bb44ef7c        79      classic
# 2  66db277a-0aca-11e7-82f6-3863bb44ef7c        82      classic
# 3  66db281e-0aca-11e7-82f6-3863bb44ef7c        83      classic
# 4  66db28b5-0aca-11e7-82f6-3863bb44ef7c       116      classic
#
#                                          rental_uris  capacity  \
# 0  {'ios': 'https://bkn.lft.to/lastmile_qr_scan',...        55
# 1  {'ios': 'https://bkn.lft.to/lastmile_qr_scan',...        33
# 2  {'ios': 'https://bkn.lft.to/lastmile_qr_scan',...        27
# 3  {'ios': 'https://bkn.lft.to/lastmile_qr_scan',...        62
# 4  {'ios': 'https://bkn.lft.to/lastmile_qr_scan',...         0
#
#    electric_bike_surcharge_waiver     rental_methods station_id short_name  \
# 0                           False  [KEY, CREDITCARD]         72    6926.01
# 1                           False  [KEY, CREDITCARD]         79    5430.08
# 2                           False  [KEY, CREDITCARD]         82    5167.06
# 3                           False  [KEY, CREDITCARD]         83    4354.07
# 4                           False  [KEY, CREDITCARD]        116    6148.02
#
#    has_kiosk eightd_station_services region_id  eightd_has_key_dispenser  \
# 0       True                      []        71                     False
# 1       True                      []        71                     False
# 2       True                      []        71                     False
# 3       True                      []        71                     False
# 4      False                      []        71                     False
#
#          lon
# 0 -73.993929
# 1 -74.006667
# 2 -74.000165
# 3 -73.976323
# 4 -74.001497

# %% [markdown]
# #### Check the Citibike region json data (I will use it later to filter only the NYC stations )

# %%
#Json file for the Citi bike station regions 
url_regions = "https://gbfs.citibikenyc.com/gbfs/en/system_regions.json"
response_regions = requests.get (url_regions)
data = response_regions.json()
data['data']['regions']
# Out:
# [{'name': 'JC District', 'region_id': '70'},
#  {'name': 'NYC District', 'region_id': '71'},
#  {'name': '8D', 'region_id': '158'},
#  {'name': 'Bronx', 'region_id': '185'},
#  {'name': 'IC HQ', 'region_id': '189'},
#  {'name': 'testzone', 'region_id': '190'},
#  {'name': 'Hoboken District', 'region_id': '311'}]

# %% [markdown]
# #### Use the Google map API to change the geo cordinate to more useful information like zipcode for visualization

# %%
#Setting up the Google Map API Key
gmaps = googlemaps.Client(key='AIzaSyDOSsHpaWdkEV5K8CytXP4D3tBAcPN7wJQ')

# %%
# testing the reverse geocoding
reverse_geocode_result = gmaps.reverse_geocode((40.767272, -73.993929))

# %%
# Look up an address with reverse geocoding - it's working
reverse_geocode = gmaps.reverse_geocode((40.767272, -73.993929), result_type="postal_code")
reverse_geocode[0]['address_components'][0]['long_name']
# Out:
# '10019'

# %%
# Add zip code to the df

def getZipCode(x):
    return gmaps.reverse_geocode((x.lat, x.lon), 
                                     result_type="postal_code")[0]['address_components'][0]['long_name']
df['zipCode'] = df.apply(getZipCode, axis=1)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [366], in <cell line: 7>()
#       4 def getZipCode(x):
#       5     return gmaps.reverse_geocode((x.lat, x.lon),
#       6                                      result_type="postal_code")[0]['address_components'][0]['long_name']
# ----> 7 df['zipCode'] = df.apply(getZipCode, axis=1)
#       9 df.head()
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [366], in getZipCode(x)
#       4 def getZipCode(x):
# ----> 5     return gmaps.reverse_geocode((x.lat, x.lon),
#       6                                      result_type="postal_code")[0]['address_components'][0]['long_name']
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/googlemaps/client.py:420, in make_api_method.<locals>.wrapper(*args, **kwargs)
#     417 @functools.wraps(func)
#     418 def wrapper(*args, **kwargs):
#     419     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 420     result = func(*args, **kwargs)
#     421     try:
#     422         del args[0]._extra_params
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/googlemaps/geocoding.py:116, in reverse_geocode(client, latlng, result_type, location_type, language)
#     113 if language:
#     114     params["language"] = language
# --> 116 return client._request("/maps/api/geocode/json", params).get("results", [])
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/googlemaps/client.py:290, in Client._request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     287     final_requests_kwargs["json"] = post_json
#     289 try:
# --> 290     response = requests_method(base_url + authed_url,
#     291                                **final_requests_kwargs)
#     292 except requests.exceptions.Timeout:
#     293     raise googlemaps.exceptions.Timeout()
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Now, clean up the data!

# %%
df.shape

# %%
# From the citibike station regions Json file
#[{'name': 'JC District', 'region_id': '70'},
#{'name': 'NYC District', 'region_id': '71'},
# {'name': '8D', 'region_id': '158'},
# {'name': 'Bronx', 'region_id': '185'},
# {'name': 'IC HQ', 'region_id': '189'},
# {'name': 'testzone', 'region_id': '190'},
# {'name': 'Hoboken District', 'region_id': '311'}]

# %%
#Drop where has_kiosk is False
df=df.loc[df["has_kiosk"] != False]

# %%
#Drop 'JC District''8D' 'IC HQ' 'testzone''Hoboken District' to only have the NYC stations
df=df.loc[df["region_id"] != '70']
df=df.loc[df["region_id"] != '158']
df=df.loc[df["region_id"] != '189']
df=df.loc[df["region_id"] != '190']
df=df.loc[df["region_id"] != '311']

# %%
df.shape

# %%
df.head()

# %%
#Drop all the unnecessary columns 
df= df.drop(['legacy_id','eightd_has_key_dispenser','rental_uris','rental_methods','electric_bike_surcharge_waiver'], axis=1)

# %%
df= df.drop(['external_id','short_name'], axis = 1)

# %%
# Save it as csv
df.to_csv('Citibike_Capacities_Cleaned.csv', index = False)

# %%
#group by the zipcode and sum up the capacity in each zipcode
zip_sum = df.groupby('zipCode').capacity.sum()
zip_sum

# %%
df.dtypes

# %%
#Merge the zip_sum into the df and call it df2
df2 = df.merge(zip_sum,
         left_on='zipCode',
         right_index=True,
         suffixes=('_original', '_zip_sum'))

# %%
df2.head()

# %%
#Save it to csv and merge it into the master df
df2.to_csv('Zip_and_total_Capacity.csv', index = False)
